# %%
import pygenometracks.plotTracks as pT
from pygenometracks.tracksClass import PlotTracks

# %%
INI_FILE = 'data/chipseq.ini'
CHR_RANGE = '8', 107543000, 107547000

# %%
trp = PlotTracks(INI_FILE, fig_width=45, fig_height=15,
                 dpi=130, track_label_width=0.2)
# Out:
# WARNING:pygenometracks.tracksClass:title not set for section 6. [genes]
#
# INFO:pygenometracks.tracksClass:initialize 1. [x-axis]
# INFO:pygenometracks.tracksClass:initialize 2. [spacer]
# INFO:pygenometracks.tracksClass:initialize 3. [H3K27ac_Control_24h_8:107542850-107547150.bg]
# 100%|██████████| 1036/1036 [00:00<00:00, 26795.71it/s]
# INFO:pygenometracks.tracksClass:initialize 4. [H3K27ac_BMP4_24h_8:107542850-107547150.bg]
# 100%|██████████| 1983/1983 [00:00<00:00, 31375.64it/s]
# INFO:pygenometracks.tracksClass:initialize 5. [H3K27ac_Noggin_24h_8:107542850-107547150.bg]
# 100%|██████████| 1501/1501 [00:00<00:00, 32049.05it/s]
# INFO:pygenometracks.tracksClass:initialize 6. [genes]
# 100%|██████████| 3/3 [00:00<00:00, 970.98it/s]
# INFO:pygenometracks.tracksClass:time initializing track(s):
# INFO:pygenometracks.tracksClass:0.18710684776306152

# %%
trp.plot('', *CHR_RANGE, title='',
         h_align_titles='right',
         decreasing_x_axis=False, save_file=False)
# Out:
# DEBUG:pygenometracks.tracksClass:Figure size in cm is 45 x 15. Dpi is set to 130
#
# INFO:pygenometracks.tracksClass:plotting 1. [x-axis]
# INFO:pygenometracks.tracksClass:plotting 2. [spacer]
# INFO:pygenometracks.tracksClass:plotting 3. [H3K27ac_Control_24h_8:107542850-107547150.bg]
# INFO:pygenometracks.tracksClass:plotting 4. [H3K27ac_BMP4_24h_8:107542850-107547150.bg]
# INFO:pygenometracks.tracksClass:plotting 5. [H3K27ac_Noggin_24h_8:107542850-107547150.bg]
# INFO:pygenometracks.tracksClass:plotting 6. [genes]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 1.08,-0.08
# array([17.71653543,  5.90551181])

# %%
fig = trp.fig
fig

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
# %matplotlib inline
fig

# %% [markdown]
# ## Cutomization

# %% [markdown]
# Changing the label:

# %%
axes = fig.get_axes()
axes[8].get_children()
# Out:
# [Text(0.9, 0.5, 'Control\\n24h'),
#  <matplotlib.spines.Spine at 0x7fab91ae3c50>,
#  <matplotlib.spines.Spine at 0x7fab91ae3dd0>,
#  <matplotlib.spines.Spine at 0x7fab91ae3f10>,
#  <matplotlib.spines.Spine at 0x7fab91af2090>,
#  <matplotlib.axis.XAxis at 0x7fab91ae3b90>,
#  <matplotlib.axis.YAxis at 0x7fab91af24d0>,
#  Text(0.5, 1, ''),
#  Text(0.0, 1, ''),
#  Text(1.0, 1, ''),
#  <matplotlib.patches.Rectangle at 0x7fab91affdd0>]

# %%
axes[8].get_children()[0].set_text('Control\n24h')

# %%
fig

# %% [markdown]
# ## Placing labels on the left side

# %%
trp.plot('', *CHR_RANGE, title='',
         h_align_titles='right',
         decreasing_x_axis=False, save_file=False, label_left=True)
# Out:
# DEBUG:pygenometracks.tracksClass:Figure size in cm is 45 x 15. Dpi is set to 130
#
# INFO:pygenometracks.tracksClass:plotting 1. [x-axis]
# INFO:pygenometracks.tracksClass:plotting 2. [spacer]
# INFO:pygenometracks.tracksClass:plotting 3. [H3K27ac_Control_24h_8:107542850-107547150.bg]
# INFO:pygenometracks.tracksClass:plotting 4. [H3K27ac_BMP4_24h_8:107542850-107547150.bg]
# INFO:pygenometracks.tracksClass:plotting 5. [H3K27ac_Noggin_24h_8:107542850-107547150.bg]
# INFO:pygenometracks.tracksClass:plotting 6. [genes]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 1.08,-0.08
# array([17.71653543,  5.90551181])
